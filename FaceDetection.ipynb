# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankith0504/Ankith0504/blob/main/FaceDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
#loading the cascade
face_cascade = cv2.CascadeClassifier('frontal_face.xml')

#Read the input image
img = cv2.imread('heroo.png')

#Detect faces
faces = face_cascade.detectMultiScale(img, 1.1, 4)

#Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

#Export the result
cv2.imwrite("reesult.png", img)
print("Pic successfully exported!!")
# Out:
# Pic successfully exported!!
